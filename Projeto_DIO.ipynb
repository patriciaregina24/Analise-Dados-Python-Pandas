# %% [markdown]
# <a href="https://colab.research.google.com/github/patriciaregina24/Analise-Dados-Python-Pandas/blob/main/Projeto_DIO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/My Drive/Datasets/Datafiniti_Fast_Food_Restaurants.csv")

# %%
df.head()
# Out:
#    index                    id             dateAdded           dateUpdated  \
# 0      0  AVwcmSyZIN2L1WUfmxyw  2015-10-19T23:47:58Z  2018-06-26T03:00:14Z
# 1      1  AVwcmSyZIN2L1WUfmxyw  2015-10-19T23:47:58Z  2018-06-26T03:00:14Z
# 2      2  AVwcopQoByjofQCxgfVa  2016-03-29T05:06:36Z  2018-06-26T02:59:52Z
# 3      3  AVweXN5RByjofQCxxilK  2017-01-03T07:46:11Z  2018-06-26T02:59:51Z
# 4      4  AWQ6MUvo3-Khe5l_j3SG  2018-06-26T02:59:43Z  2018-06-26T02:59:43Z
#
#                 address                                    categories  \
# 0      800 N Canal Blvd  American Restaurant and Fast Food Restaurant
# 1      800 N Canal Blvd                         Fast Food Restaurants
# 2   206 Wears Valley Rd                          Fast Food Restaurant
# 3          3652 Parkway                                     Fast Food
# 4  2118 Mt Zion Parkway                          Fast Food Restaurant
#
#            city country                                           keys  \
# ...

# %%
df.tail()
# Out:
#       index                    id             dateAdded           dateUpdated  \
# 9995   9995  AV12gJwna4HuVbed9Ayg  2017-07-24T21:28:46Z  2018-04-07T13:19:06Z
# 9996   9996  AV12gJxKIxWefVJwhpzS  2017-07-24T21:28:46Z  2018-04-07T13:19:05Z
# 9997   9997  AVwdJMdSByjofQCxl8Vr  2015-10-24T00:17:32Z  2018-04-07T13:19:05Z
# 9998   9998  AVwdl2cykufWRAb57ZPs  2016-04-05T02:59:45Z  2018-04-07T13:19:05Z
# 9999   9999  AVwdecWKIN2L1WUfwMWU  2016-11-08T02:26:32Z  2018-04-07T13:19:05Z
#
#                    address             categories           city country  \
# 9995     3460 Robinhood Rd  Fast Food Restaurants  Winston-Salem      US
# 9996  3069 Kernersville Rd  Fast Food Restaurants  Winston-Salem      US
# 9997         838 S Main St  Fast Food Restaurants   Kernersville      US
# 9998   1702 Glendale Dr SW  Fast Food Restaurants         Wilson      US
# 9999       1405 W Broad St  Fast Food Restaurants  Elizabethtown      US
#
# ...

# %%
df = df.rename(columns={"index":"Índice", "dateAdded":"Data Add", "dateUpdated": "Data Atualização", "address":"Endereço", "categories":"Categorias", "city":"Cidade", "country":"País", "keys":"Chaves", "name":"Nome", "postalCode":"Código Postal", "province":"Estado"})
df.head()
# Out:
#    Índice                    id              Data Add      Data Atualização  \
# 0       0  AVwcmSyZIN2L1WUfmxyw  2015-10-19T23:47:58Z  2018-06-26T03:00:14Z
# 1       1  AVwcmSyZIN2L1WUfmxyw  2015-10-19T23:47:58Z  2018-06-26T03:00:14Z
# 2       2  AVwcopQoByjofQCxgfVa  2016-03-29T05:06:36Z  2018-06-26T02:59:52Z
# 3       3  AVweXN5RByjofQCxxilK  2017-01-03T07:46:11Z  2018-06-26T02:59:51Z
# 4       4  AWQ6MUvo3-Khe5l_j3SG  2018-06-26T02:59:43Z  2018-06-26T02:59:43Z
#
#                Endereço                                    Categorias  \
# 0      800 N Canal Blvd  American Restaurant and Fast Food Restaurant
# 1      800 N Canal Blvd                         Fast Food Restaurants
# 2   206 Wears Valley Rd                          Fast Food Restaurant
# 3          3652 Parkway                                     Fast Food
# 4  2118 Mt Zion Parkway                          Fast Food Restaurant
#
#          Cidade País                                         Chaves  \
# ...

# %%
df.shape
df.columns
# Out:
# Index(['Índice', 'id', 'Data Add', 'Data Atualização', 'Endereço',
#        'Categorias', 'Cidade', 'País', 'Chaves', 'latitude', 'longitude',
#        'Nome', 'Código Postal', 'Estado', 'sourceURLs', 'websites'],
#       dtype='object')

# %%
df.describe()
# Out:
#             Índice      latitude     longitude
# count  10000.00000  10000.000000  10000.000000
# mean    4999.50000     37.337400    -93.106515
# std     2886.89568      5.100276     15.787614
# min        0.00000     19.504168   -159.378066
# 25%     2499.75000     33.773973   -102.891796
# 50%     4999.50000     37.706263    -87.951148
# 75%     7499.25000     41.140722    -81.454907
# max     9999.00000     64.840240    -67.463019
